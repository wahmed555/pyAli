# %%
import numpy as np
import pandas as pd

# %%
df0=pd.read_excel('CBD Shops.xlsx')
df0
# Out:
#       CBD Shops   Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0     CBD Shops          NaN         NaN         NaN
# 1     CBD Shops          NaN         NaN         NaN
# 2     CBD Shops          NaN         NaN         NaN
# 3     CBD Shops          NaN         NaN         NaN
# 4     CBD Shops          NaN         NaN         NaN
# ...          ...         ...         ...         ...
# 2757  CBD Shops          NaN         NaN         NaN
# 2758  CBD Shops          NaN         NaN         NaN
# 2759  CBD Shops          NaN         NaN         NaN
# 2760  CBD Shops          NaN         NaN         NaN
# 2761  CBD Shops          NaN         NaN         NaN
#
#                    The CBD Shop  \
# 0                        Harmon
# 1     The CBD Store - Riverside
# 2     The CBD Store - Riverside
# 3                Rocketman Shop
# 4                      502 Hemp
# ...                         ...
# 2757      Windsor Beauty Supply
# 2758               Twisted Leaf
# ...

# %%
df0.drop_duplicates(subset ="(985) 206-5092", 
                     keep = 'last' , inplace = True)
df0
# Out:
#       CBD Shops   Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0     CBD Shops          NaN         NaN         NaN
# 2     CBD Shops          NaN         NaN         NaN
# 3     CBD Shops          NaN         NaN         NaN
# 4     CBD Shops          NaN         NaN         NaN
# 5     CBD Shops          NaN         NaN         NaN
# ...          ...         ...         ...         ...
# 2757  CBD Shops          NaN         NaN         NaN
# 2758  CBD Shops          NaN         NaN         NaN
# 2759  CBD Shops          NaN         NaN         NaN
# 2760  CBD Shops          NaN         NaN         NaN
# 2761  CBD Shops          NaN         NaN         NaN
#
#                    The CBD Shop  \
# 0                        Harmon
# 2     The CBD Store - Riverside
# 3                Rocketman Shop
# 4                      502 Hemp
# 5              704Hemp CBD shop
# ...                         ...
# 2757      Windsor Beauty Supply
# 2758               Twisted Leaf
# ...

# %%
df0.columns
# Out:
# Index([                                     'CBD Shops ',
#                                             'Unnamed: 1',
#                                             'Unnamed: 2',
#                                             'Unnamed: 3',
#                                           'The CBD Shop',
#        '4958 Louisiana Highway 22, Mandeville, LA 70471',
#                                         30.4038162231445,
#                                        -90.1195602416992,
#                                         '(985) 206-5092',
#                     'http://www.thecannabidiolshop.com/',
#                              '4958 Louisiana Highway 22',
#                                             'Mandeville',
#                                                     'LA',
#                                                    70471,
#                                            'Unnamed: 14',
#                           ' info@thecannabidiolshop.com',
# ...

# %%
df0.to_excel('CBD_shops_duplicate_removed.xlsx')
